# %%
import pandas as pd

# %%
df = pd.read_csv("./data/jc_citibike_tripdata.csv")
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# ...

# %%
# clean up
print(df.isnull().sum())
df_clean = df.dropna()
print("after clean_up")
print(df_clean.isnull().sum())
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       0
# start_station_id         0
# end_station_name      3247
# end_station_id        3247
# start_lat                0
# start_lng                0
# end_lat                954
# end_lng                954
# member_casual            0
# dtype: int64
# after clean_up
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %%
df_clean.to_csv("jc_citibike_tripdata_cl.csv", index=False)

# %%
# how many unique stations
df_clean.start_station_id.unique()
# Out:
# array(['HB101', 'JC009', 'JC103', 'JC102', 'HB402', 'HB305', 'JC098',
#        'JC084', 'JC035', 'JC059', 'JC024', 'HB302', 'JC034', 'JC002',
#        'JC018', 'HB607', 'JC109', 'HB501', 'JC038', 'HB201', 'JC104',
#        'HB601', 'JC053', 'JC093', 'JC107', 'JC105', 'HB502', 'HB304',
#        'JC003', 'JC080', 'JC072', 'HB603', 'JC099', 'JC110', 'HB404',
#        'JC063', 'JC076', 'JC074', 'HB105', 'HB301', 'JC075', 'JC115',
#        'JC082', 'JC057', 'HB408', 'JC013', 'JC020', 'JC078', 'HB503',
#        'JC108', 'JC019', 'JC022', 'HB505', 'HB401', 'HB202', 'HB303',
#        'HB203', 'JC052', 'JC097', 'JC027', 'HB602', 'HB507', 'JC106',
#        'JC008', 'JC006', 'JC094', 'HB102', 'HB506', 'JC065', 'JC032',
#        'JC081', 'JC051', 'JC095', 'JC066', 'HB407', 'JC055', 'JC077',
#        'HB409', 'JC023', 'HB103', 'JC014', '5532.01', 'HB608', 'JC116',
#        '4317.05', '6839.10', '6140.05', '4993.02', '4683.02', '6459.04',
# ...

# %%
df_clean.start_station_name.unique()
# Out:
# array(['Hoboken Terminal - Hudson St & Hudson Pl', 'Hamilton Park',
#        'Journal Square', 'Grand St', 'Madison St & 1 St',
#        '9 St HBLR - Jackson St & 8 St', 'Washington St',
#        'Communipaw & Berry Lane', 'Van Vorst Park', 'Heights Elevator',
#        'Pershing Field', '6 St & Grand St', 'Christ Hospital',
#        'Paulus Hook', '5 Corners Library', 'Hudson St & 4 St',
#        'Bergen Ave & Sip Ave', 'Columbus Park - Clinton St & 9 St',
#        'Essex Light Rail', '12 St & Sinatra Dr N', 'Harborside',
#        'Church Sq Park - 5 St & Park Ave', 'Lincoln Park',
#        'Fairmount Ave', 'Grant Ave & MLK Dr',
#        'Hoboken Ave at Monmouth St', '11 St & Washington St',
#        '7 St & Monroe St', 'City Hall', 'Leonard Gordon Park',
#        'Morris Canal', '8 St & Washington St', 'Montgomery St',
#        'JC Medical Center', 'Mama Johnson Field - 4 St & Jackson St',
#        'Jackson Square', 'Dixon Mills', 'Jersey & 3rd',
# ...

# %%
print(df_clean.groupby('start_station_name').ride_id.count().sort())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/vk/qp1jcvg16z90njgkx_dqnl_c0000gn/T/ipykernel_11964/399955119.py in ?()
# ----> 1 print(df_clean.groupby('start_station_name').ride_id.count().sort())
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort'
